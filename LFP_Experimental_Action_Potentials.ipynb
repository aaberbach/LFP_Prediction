# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import fastai
#from fastai.text import *
from fastai.vision import *
from fastai.utils.mem import *
#from fastai.tabular import *
import scipy.signal as s
import scipy.stats as stats
#import pyts
from itertools import chain 
from fastai.callbacks import *
import sklearn.metrics as smetrics

# %%
#replace noise with 0s then filter, dont include in training.

# %%
#normalize traces
#make plot of burst including raw
#go back to forecasting

# %%
path = Path("data/LFP_Prediction/NewExperimentalData")

# %%
path.ls()
# Out:
# [WindowsPath('data/LFP_Prediction/NewExperimentalData/experimental_filtered.csv'),
#  WindowsPath('data/LFP_Prediction/NewExperimentalData/experimental_normed.csv'),
#  WindowsPath('data/LFP_Prediction/NewExperimentalData/feathers'),
#  WindowsPath('data/LFP_Prediction/NewExperimentalData/trace_one_labels.csv')]

# %%
f_path = path/"feathers"

# %%
f_path.ls()
# Out:
# [WindowsPath('data/LFP_Prediction/NewExperimentalData/feathers/225_275_ecp_feather'),
#  WindowsPath('data/LFP_Prediction/NewExperimentalData/feathers/275_325_ecp_feather'),
#  WindowsPath('data/LFP_Prediction/NewExperimentalData/feathers/325_375_ecp_feather'),
#  WindowsPath('data/LFP_Prediction/NewExperimentalData/feathers/375_425_ecp_feather'),
#  WindowsPath('data/LFP_Prediction/NewExperimentalData/feathers/425_475_ecp_feather'),
#  WindowsPath('data/LFP_Prediction/NewExperimentalData/feathers/475_525_ecp_feather'),
#  WindowsPath('data/LFP_Prediction/NewExperimentalData/feathers/525_575_ecp_feather'),
#  WindowsPath('data/LFP_Prediction/NewExperimentalData/feathers/575_625_ecp_feather'),
#  WindowsPath('data/LFP_Prediction/NewExperimentalData/feathers/625_675_ecp_feather'),
#  WindowsPath('data/LFP_Prediction/NewExperimentalData/feathers/675_725_ecp_feather'),
#  WindowsPath('data/LFP_Prediction/NewExperimentalData/feathers/725_775_ecp_feather'),
# ...

# %%
df = pd.read_feather(f_path.ls()[0])

# %%
trace = np.array(df["0"])

# %%
len(trace)
# Out:
# 1500000

# %%
plt.plot(trace[:1000])

# %%
trace = stats.zscore(trace)

# %%
b, a = s.butter(2, [500], btype="high", fs = 30000)

# %%
spikes = s.filtfilt(b, a, trace)

# %%
for i in range(0, len(spikes), 20000):
    plt.plot(spikes[i:i+500])
    #plt.plot(np.full(500, 180))
    plt.show()
